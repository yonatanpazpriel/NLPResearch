# %%
import pandas as pd
import re

# %%
# Load CSV file into a DataFrame
texts = pd.read_csv('texts.csv')
texts
# Out:
#                                        file_name  \
# 0     8-11-20 Kravitz and Hernandez_embedded.txt
# 1                      8-11-20 Misa_embedded.txt
# 2          8-11-20 Silverberg-Rajna_embedded.txt
# 3                   8-7-20 Schwartz_embedded.txt
# 4                  8-11-20 Christie_embedded.txt
# ...                                          ...
# 6776                  12-29-20 Fine_embedded.txt
# 6777                12-30-20 Gerber_embedded.txt
# 6778              1-20-21 Goldstein_embedded.txt
# 6779                  1-19-21 Ayala_embedded.txt
# 6780             1-19-21 Gharpetian_embedded.txt
#
#                                             folder_name  \
# 0     Comments received after 7-31-20 posting_embedd...
# 1     Comments received after 7-31-20 posting_embedd...
# 2     Comments received after 7-31-20 posting_embedd...
# 3     Comments received after 7-31-20 posting_embedd...
# 4     Comments received after 7-31-20 posting_embedd...
# ...                                                 ...
# 6776  Third Field Review (Dec 2020 - Jan 2021)_embed...
# 6777  Third Field Review (Dec 2020 - Jan 2021)_embed...
# 6778  Third Field Review (Dec 2020 - Jan 2021)_embed...
# 6779  Third Field Review (Dec 2020 - Jan 2021)_embed...
# 6780  Third Field Review (Dec 2020 - Jan 2021)_embed...
#
#                                       preprocessed_text
# 0     august california department education n stree...
# 1     misa fagasavali sent tuesday august ethnic stu...
# 2     shana sent monday august pm ethnic study cc em...
# 3     ruth schwartz sent thursday august pm ethnic s...
# 4     elizabeth christie sent tuesday august ethnic ...
# ...                                                 ...
# 6776  celia fine sent monday december pm ethnic stud...
# 6777  mike gerber sent tuesday december pm joe nalve...
# 6778  sondra goldstein sent tuesday january pm ethni...
# 6779  samantha ayala sent tuesday january pm ethnic ...
# 6780  armina gharpetian sent sunday january pm suzie...
#
# [6781 rows x 3 columns]

# %%
def extract_name(filename):
    pattern = r'\d{1,2}-\d{1,2}-\d{2} (\w+)_embedded\.txt'
    match = re.search(pattern, filename)
    if match:
        # Convert the name to lowercase
        return match.group(1).lower()
    return None  # Return None if no match is found

# Apply the function to extract names and create a new column 'name'
texts['name'] = texts['file_name'].apply(extract_name)
texts[texts['file_name'] == 'Shugarman_embedded.txt']
# Out:
# Empty DataFrame
# Columns: [file_name, folder_name, preprocessed_text, name]
# Index: []

# %%
def extract_full_name(row):
    last_name = row['name']
    text = row['preprocessed_text']
    
    if last_name is None:  # Check if last name is None
        return None  # Or handle it differently if needed

    # Regex to match the full name (assuming the first name precedes the last name)
    pattern = r'(\b\w+\b) ' + re.escape(last_name)  # Matches first name followed by last name
    match = re.search(pattern, text)
    
    return match.group(1) if match else None  # Return first name or None if not found


# Apply the function to create a new column 'first_name'
texts['first_name'] = texts.apply(extract_full_name, axis=1)
texts['author'] = texts['first_name'] + ' ' + texts['name']
texts
# Out:
#                                        file_name  \
# 0     8-11-20 Kravitz and Hernandez_embedded.txt
# 1                      8-11-20 Misa_embedded.txt
# 2          8-11-20 Silverberg-Rajna_embedded.txt
# 3                   8-7-20 Schwartz_embedded.txt
# 4                  8-11-20 Christie_embedded.txt
# ...                                          ...
# 6776                  12-29-20 Fine_embedded.txt
# 6777                12-30-20 Gerber_embedded.txt
# 6778              1-20-21 Goldstein_embedded.txt
# 6779                  1-19-21 Ayala_embedded.txt
# 6780             1-19-21 Gharpetian_embedded.txt
#
#                                             folder_name  \
# 0     Comments received after 7-31-20 posting_embedd...
# 1     Comments received after 7-31-20 posting_embedd...
# 2     Comments received after 7-31-20 posting_embedd...
# 3     Comments received after 7-31-20 posting_embedd...
# 4     Comments received after 7-31-20 posting_embedd...
# ...                                                 ...
# 6776  Third Field Review (Dec 2020 - Jan 2021)_embed...
# 6777  Third Field Review (Dec 2020 - Jan 2021)_embed...
# 6778  Third Field Review (Dec 2020 - Jan 2021)_embed...
# 6779  Third Field Review (Dec 2020 - Jan 2021)_embed...
# 6780  Third Field Review (Dec 2020 - Jan 2021)_embed...
#
#                                       preprocessed_text        name  \
# 0     august california department education n stree...        None
# 1     misa fagasavali sent tuesday august ethnic stu...        misa
# 2     shana sent monday august pm ethnic study cc em...        None
# 3     ruth schwartz sent thursday august pm ethnic s...    schwartz
# 4     elizabeth christie sent tuesday august ethnic ...    christie
# ...                                                 ...         ...
# 6776  celia fine sent monday december pm ethnic stud...        fine
# 6777  mike gerber sent tuesday december pm joe nalve...      gerber
# 6778  sondra goldstein sent tuesday january pm ethni...   goldstein
# 6779  samantha ayala sent tuesday january pm ethnic ...       ayala
# 6780  armina gharpetian sent sunday january pm suzie...  gharpetian
#
#      first_name              author
# 0          None                 NaN
# 1     sincerely      sincerely misa
# 2          None                 NaN
# 3          ruth       ruth schwartz
# 4     elizabeth  elizabeth christie
# ...         ...                 ...
# 6776      celia          celia fine
# 6777       mike         mike gerber
# 6778     sondra    sondra goldstein
# 6779   samantha      samantha ayala
# 6780     armina   armina gharpetian
#
# [6781 rows x 6 columns]

# %%
texts.isna().sum()
# Out:
# file_name               0
# folder_name             0
# preprocessed_text       0
# name                 1050
# first_name           1477
# author               1477
# dtype: int64

# %%
texts[(texts['name'].notna()) & (texts['first_name'].isna())]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 texts[(texts['name'].notna()) & (texts['first_name'].isna())]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'name'

# %%
texts[texts['preprocessed_text'].str.contains('california department education received', case=False, na=False)]
# Out:
#                                               file_name  \
# 204   8-6-20 Group Letter Positive Changes and Flaws...
# 311    8-11-20 Group Letter Major Concerns_embedded.txt
# 350   8-10-20 Group Letter West Asian Community_embe...
# 390                8-6-20 Group Attachment_embedded.txt
# 533    8-5-20 Group Comment Talking Points_embedded.txt
# ...                                                 ...
# 6713  1-20-21 Group Letter Jewish Americans 3_embedd...
# 6728    12-8-20 Group Letter Arab American_embedded.txt
# 6765  12-18-20 Group Letter Jewish Americans_embedde...
# 6773  12-14-20 Group Letter Keep Jews Included_embed...
# 6775  12-17-20 Group Letter Arab Americans 3_embedde...
#
#                                             folder_name  \
# 204   Comments received after 7-31-20 posting_embedd...
# 311   Comments received after 7-31-20 posting_embedd...
# 350   Comments received after 7-31-20 posting_embedd...
# 390   Comments received after 7-31-20 posting_embedd...
# 533   Comments received after 7-31-20 posting_embedd...
# ...                                                 ...
# 6713  Third Field Review (Dec 2020 - Jan 2021)_embed...
# 6728  Third Field Review (Dec 2020 - Jan 2021)_embed...
# 6765  Third Field Review (Dec 2020 - Jan 2021)_embed...
# 6773  Third Field Review (Dec 2020 - Jan 2021)_embed...
# 6775  Third Field Review (Dec 2020 - Jan 2021)_embed...
#
#                                       preprocessed_text
# 204   california department education received addit...
# 311   california department education received addit...
# 350   california department education received submi...
# 390   california department education received addit...
# 533   california department education received email...
# ...                                                 ...
# 6713  california department education received submi...
# 6728  california department education received addit...
# 6765  california department education received submi...
# 6773  california department education received submi...
# 6775  california department education received submi...
#
# [85 rows x 3 columns]

# %%
x = all_files[all_files['text'].str.len() <= 75]
#x.to_csv('incorrectlyExtracted.csv', index=False)
x
# Out:
#       Unnamed: 0                           file_name  \
# 4327        4327                     8-13-19 Cox.pdf
# 6851        6852                           Gilly.pdf
# 6881        6882            9-30-19 Fisher et al.pdf
# 6883        6884                       Greenbaum.pdf
# 6888        6889                               H.pdf
# 6910        6911                           Lavic.pdf
# 6932        6933                       Shugarman.pdf
# 6967        6968                           Rones.pdf
# 6991        6992                          Draper.pdf
# 6995        6996                      Kean  Gold.pdf
# 7000        7001                      Brunshteyn.pdf
# 7020        7021                10-21-19 Coodley.pdf
# 7026        7027                        Guelfand.pdf
# 7027        7028                        Lebowitz.pdf
# 7041        7042                       Caballero.pdf
# 7046        7047                           Young.pdf
# 7054        7055                            Fuks.pdf
# 7077        7078                          Alkana.pdf
# 7094        7095                       Lieberman.pdf
# 7096        7097                        Northrup.pdf
# 7098        7099                        Baruch 2.pdf
# 7105        7106                   9-17-19 Gatto.pdf
# 7110        7111                           Sacks.pdf
# 7113        7114                 8-30-19 Sleeter.pdf
# 7116        7117                   9-6-19 Kaiser.pdf
# 7117        7118        7-17-20 Portantino et al.pdf
# 7128        7129                         Cirocco.pdf
# 7160        7161                8-22-19 Kehlmann.pdf
# 7165        7166                             Yee.pdf
# 7175        7176                          Gilboa.pdf
# 7200        7201                         Abigail.pdf
# 7217        7218                         Bradley.pdf
# 7298        7299                     9-3-19 Wynn.pdf
# 7300        7301  1-16-20 Save CA Ethnic Studies.pdf
# 7325        7326                           Eshoo.pdf
# 7342        7343               10-21-19 Huckabay.pdf
# 7358        7359                       Robertson.pdf
# 7363        7364                  Wiener  Gloria.pdf
# 7426        7427                       Gallagher.pdf
# 7452        7453                  9-5-19 Cerruti.pdf
# 7485        7486                           Ariel.pdf
# 7506        7507                       9-5-19 Ma.pdf
# 7507        7508                             ADL.pdf
# 7525        7526                               B.pdf
# 7526        7527                 1-9-20 Adelberg.pdf
# 7531        7532                          Rutman.pdf
# 7544        7545                         Musayev.pdf
# 7566        7567                          Baruch.pdf
# 7570        7571                       Velazquez.pdf
# 7578        7579                           Plack.pdf
# 7587        7588                           Lahav.pdf
# 7593        7594                            Moss.pdf
# 7605        7606               8-26-19 Breslauer.pdf
# 7620        7621                           Roder.pdf
# 7628        7629                          Bertet.pdf
#
#                                   folder_name  \
# 4327  First Field Review (June - August 2019)
# 6851     Comments Received After Field Review
# 6881     Comments Received After Field Review
# 6883     Comments Received After Field Review
# 6888     Comments Received After Field Review
# 6910     Comments Received After Field Review
# 6932     Comments Received After Field Review
# 6967     Comments Received After Field Review
# 6991     Comments Received After Field Review
# 6995     Comments Received After Field Review
# 7000     Comments Received After Field Review
# 7020     Comments Received After Field Review
# 7026     Comments Received After Field Review
# 7027     Comments Received After Field Review
# 7041     Comments Received After Field Review
# 7046     Comments Received After Field Review
# 7054     Comments Received After Field Review
# 7077     Comments Received After Field Review
# 7094     Comments Received After Field Review
# 7096     Comments Received After Field Review
# 7098     Comments Received After Field Review
# 7105     Comments Received After Field Review
# 7110     Comments Received After Field Review
# 7113     Comments Received After Field Review
# 7116     Comments Received After Field Review
# 7117     Comments Received After Field Review
# 7128     Comments Received After Field Review
# 7160     Comments Received After Field Review
# 7165     Comments Received After Field Review
# 7175     Comments Received After Field Review
# 7200     Comments Received After Field Review
# 7217     Comments Received After Field Review
# 7298     Comments Received After Field Review
# 7300     Comments Received After Field Review
# 7325     Comments Received After Field Review
# 7342     Comments Received After Field Review
# 7358     Comments Received After Field Review
# 7363     Comments Received After Field Review
# 7426     Comments Received After Field Review
# 7452     Comments Received After Field Review
# 7485     Comments Received After Field Review
# 7506     Comments Received After Field Review
# 7507     Comments Received After Field Review
# 7525     Comments Received After Field Review
# 7526     Comments Received After Field Review
# 7531     Comments Received After Field Review
# 7544     Comments Received After Field Review
# 7566     Comments Received After Field Review
# 7570     Comments Received After Field Review
# 7578     Comments Received After Field Review
# 7587     Comments Received After Field Review
# 7593     Comments Received After Field Review
# 7605     Comments Received After Field Review
# 7620     Comments Received After Field Review
# 7628     Comments Received After Field Review
#
#                                         text  submissions    weight
# 4327  Scanned by CamScanner\r\n\r\n\r\n\r\n
#             1  0.000018
# 6851
#             1  0.000017
# 6881
#
#             1  0.000017
# 6883
#             1  0.000017
# 6888
#             1  0.000017
# 6910
#             1  0.000017
# 6932
#             1  0.000017
# 6967
#             1  0.000017
# 6991
#             1  0.000017
# 6995
#             1  0.000017
# 7000
#             1  0.000017
# 7020
#             1  0.000017
# 7026
#             1  0.000017
# 7027
#
#             1  0.000017
# 7041
#
#             1  0.000017
# 7046
#
#             1  0.000017
# 7054
#             1  0.000017
# 7077
#
#             1  0.000017
# 7094
#             1  0.000017
# 7096
#             1  0.000017
# 7098
#             1  0.000017
# 7105
#             1  0.000017
# 7110
#             1  0.000017
# 7113
#
#             1  0.000017
# 7116
#
#             1  0.000017
# 7117
#
#
#
#             1  0.000017
# 7128
#             1  0.000017
# 7160
#             1  0.000017
# 7165
#             1  0.000017
# 7175
#
#
#
#
#
#
#             1  0.000017
# 7200
#             1  0.000017
# 7217
#             1  0.000017
# 7298
#
#             1  0.000017
# 7300
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             1  0.000017
# 7325
#
#             1  0.000017
# 7342
#             1  0.000017
# 7358
#             1  0.000017
# 7363
#
#             1  0.000017
# 7426
#
#             1  0.000017
# 7452
#
#
#
#             1  0.000017
# 7485
#             1  0.000017
# 7506
#             1  0.000017
# 7507                            Th\r\n\r\n
#
#             1  0.000017
# 7525
#             1  0.000017
# 7526
#
#             1  0.000017
# 7531
#
#
#
#
#
#
#
#
#
#             1  0.000017
# 7544
#
#             1  0.000017
# 7566
#             1  0.000017
# 7570
#             1  0.000017
# 7578
#             1  0.000017
# 7587
#             1  0.000017
# 7593
#             1  0.000017
# 7605
#
#
#
#
#
#
#
#
#
#
#             1  0.000017
# 7620
#
#             1  0.000017
# 7628
#
#             1  0.000017

# %%
x['file_name']
all_files
# Out:
#       Unnamed: 0                    file_name  \
# 0              0            11-13-20 Khan.pdf
# 1              1       11-13-20 Solkovits.pdf
# 2              2  11-13-20 Kaur and Singh.pdf
# 3              3          11-19-20 Lamont.pdf
# 4              4          11-18-20 Jensen.pdf
# ...          ...                          ...
# 7712        7713          10-27-20 Parker.pdf
# 7713        7714          10-30-20 Parker.pdf
# 7714        7715            10-22-20 Nash.pdf
# 7715        7716        10-27-20 Parker 2.pdf
# 7716        7717        10-27-20 Fishkoff.pdf
#
#                                      folder_name  \
# 0     Comments Received After September 30, 2020
# 1     Comments Received After September 30, 2020
# 2     Comments Received After September 30, 2020
# 3     Comments Received After September 30, 2020
# 4     Comments Received After September 30, 2020
# ...                                          ...
# 7712  Comments Received After September 30, 2020
# 7713  Comments Received After September 30, 2020
# 7714  Comments Received After September 30, 2020
# 7715  Comments Received After September 30, 2020
# 7716  Comments Received After September 30, 2020
#
#                                                    text  submissions    weight
# 0     From: Hareem Khan Sent: Thursday, November 12,...            1  0.000008
# 1     From: gs <gsolk@aol.com> Sent: Thursday, Novem...            1  0.000008
# 2     November 13th, 2020\r\n\r\nDear Superintendent...            1  0.000008
# 3     From: Sami Lamont Sent: Wednesday, November 18...            1  0.000008
# 4     From: Sine Hwang Jensen Sent: Tuesday, Novembe...            1  0.000008
# ...                                                 ...          ...       ...
# 7712  From: Ruth Parker\r\nSent: Monday, October 26,...            1  0.000008
# 7713  From: Ruth Parker\r\nSent: Friday, October 30,...            1  0.000008
# 7714  Amin Nash, M.A. 10.21.2020\r\n\r\n1\r\n\r\nTo ...            1  0.000008
# 7715  From: Ruth Parker\r\nSent: Tuesday, October 27...            1  0.000008
# 7716  From: Sue Fishkoff\r\nSent: Monday, October 26...            1  0.000008
#
# [7717 rows x 6 columns]
