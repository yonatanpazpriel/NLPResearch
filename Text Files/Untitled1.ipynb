# %%
import pandas as pd
all = pd.read_csv("csv files/all_files.csv")
all
# Out:
#                                          file_name  \
# 0                       11-13-20 Khan_embedded.txt
# 1                  11-13-20 Solkovits_embedded.txt
# 2             11-13-20 Kaur and Singh_embedded.txt
# 3                     11-19-20 Lamont_embedded.txt
# 4                     11-18-20 Jensen_embedded.txt
# ...                                            ...
# 6845  9-30-20 Lee and Fa 2 Attachment_embedded.txt
# 6846                  9-16-20 Galper _embedded.txt
# 6847                   9-30-20 gruen _embedded.txt
# 6848                  9-30-20 bayarea_embedded.txt
# 6849                   9-29-20 Rapson_embedded.txt
#
#                                             folder_name  \
# 0     Comments received after 11-6-20 posting_embedd...
# 1     Comments received after 11-6-20 posting_embedd...
# 2     Comments received after 11-6-20 posting_embedd...
# 3     Comments received after 11-6-20 posting_embedd...
# 4     Comments received after 11-6-20 posting_embedd...
# ...
