# %%
import pandas as pd
import os
import subprocess

incorrectDF = pd.read_csv('incorrectlyExtracted.csv')
incorrectFiles = incorrectDF['file_name']

current_dir = os.getcwd()
parent_of_parent_dir = os.path.abspath(os.path.join(current_dir, "../../../"))
print(len(incorrectFiles))
x=1

for fileName in incorrectFiles:
    filepath = None
    for root, dirs, files in os.walk(parent_of_parent_dir):
        if fileName in files:
            file_path = os.path.join(root, fileName)
# Out:
# 55
# 1   C:\Users\yonat\OneDrive\Desktop\ethnicStudiesNLP\ethnicStudiesNLPResearch\count_files\First Field Review (June - August 2019)\First Field Review (June - August 2019)\8-13-19 Cox.pdf
# 1   C:\Users\yonat\OneDrive\Desktop\ethnicStudiesNLP\ethnicStudiesNLPResearch\First Field Review (June - August 2019)\First Field Review (June - August 2019)\8-13-19 Cox.pdf
# 2   C:\Users\yonat\OneDrive\Desktop\ethnicStudiesNLP\ethnicStudiesNLPResearch\Comments Received After Field Review\Gilly.pdf
# 3   C:\Users\yonat\OneDrive\Desktop\ethnicStudiesNLP\ethnicStudiesNLPResearch\Comments Received After Field Review\9-30-19 Fisher et al.pdf
# 4   C:\Users\yonat\OneDrive\Desktop\ethnicStudiesNLP\ethnicStudiesNLPResearch\Comments Received After Field Review\Greenbaum.pdf
# 5   C:\Users\yonat\OneDrive\Desktop\ethnicStudiesNLP\ethnicStudiesNLPResearch\Comments Received After Field Review\H.pdf
# ...

# %%
len(r"C:\Users\yonat\OneDrive\Desktop\ethnicStudiesNLP\ethnicStudiesNLPResearch\Comments Received After Field Review")
r"C:\Users\yonat\OneDrive\Desktop\ethnicStudiesNLP\ethnicStudiesNLPResearch\Comments Received After Field Review\\"[:110]
# Out:
# 'C:\\Users\\yonat\\OneDrive\\Desktop\\ethnicStudiesNLP\\ethnicStudiesNLPResearch\\Comments Received After Field Review'

# %%
input_directory = "../Third Field Review (Dec 2020 - Jan 2021)" # Adjust this path to the input folder containing PDFs to convert.

# Function to check if it's embedded text-based PDF, or image/errors
def is_text_based(pdf_path):
    try: #hm
        text = textract.process(pdf_path)
        return bool(text.strip())
    except Exception as e:
        return False

num_embedded, num_images, errors = 0, 0, 0

for filename in n_files:    
        
    if filename.endswith(".pdf"):  # Process only PDF files (skip any .txt files)
        pdf_path = os.path.join(input_directory, filename)
        print(pdf_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 13
#       9         return False
#      11 num_embedded, num_images, errors = 0, 0, 0
# ---> 13 if curr_index + n < len(files):
#      14     #n_files = files[curr_index : curr_index + n] # move n files along
#      15     print('indices processed: ', curr_index, curr_index + n)
#      16 else:
#
# NameError: name 'curr_index' is not defined

# %%
import fitz
parent_of_parent_directory = os.path.abspath(os.path.join(os.getcwd(), "..", "..", ".."))
print(parent_of_parent_directory)
x = "../Comments Received After Field Review"
pdf_path = os.path.join(x, 'Rutman.pdf')
print(pdf_path)
pdf_document = fitz.open( r'C:\Users\yonat\OneDrive\Desktop\ethnicStudiesNLP\ethnicStudiesNLPResearch\Comments Received After Field Review\Rutman.pdf')

# Iterate through pages and extract text
for page_num in range(len(pdf_document)):
    page = pdf_document[page_num]
    text = page.get_text()
    print(f"Page {page_num + 1}:\n{text}\n")

# Close the PDF document
pdf_document.close()
# Out:
# C:\Users\yonat\OneDrive\Desktop\ethnicStudiesNLP\ethnicStudiesNLPResearch
# ../Comments Received After Field Review\Rutman.pdf
# Page 1:
#
#
# Page 2:
#
#
# Page 3:
#
#
# Page 4:
#
#
# Page 5:
#
#
# Page 6:
#
#
# Page 7:
#
#
# Page 8:
#
#
# Page 9:
#
#
# Page 10:
