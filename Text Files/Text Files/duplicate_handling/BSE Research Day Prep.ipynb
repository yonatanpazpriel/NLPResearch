# %%
import pandas as pd
# Out:
# /Users/maryamzakiyya/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('all_files.csv')

# %%
df
# Out:
#       Unnamed: 0                    file_name  \
# 0              0            11-13-20 Khan.pdf
# 1              1       11-13-20 Solkovits.pdf
# 2              2  11-13-20 Kaur and Singh.pdf
# 3              3          11-19-20 Lamont.pdf
# 4              4          11-18-20 Jensen.pdf
# ...          ...                          ...
# 7712        7713          10-27-20 Parker.pdf
# 7713        7714          10-30-20 Parker.pdf
# 7714        7715            10-22-20 Nash.pdf
# 7715        7716        10-27-20 Parker 2.pdf
# 7716        7717        10-27-20 Fishkoff.pdf
#
#                                      folder_name  submissions    weight  \
# 0     Comments Received After September 30, 2020            1  0.000008
# 1     Comments Received After September 30, 2020            1  0.000008
# 2     Comments Received After September 30, 2020            1  0.000008
# 3     Comments Received After September 30, 2020            1  0.000008
# ...

# %%
armenia = df[df['text'].str.contains('armenia', case=False)]
armenia
# Out:
#       Unnamed: 0                                         file_name  \
# 1              1                            11-13-20 Solkovits.pdf
# 19            19                          11-13-20 Armen et al.pdf
# 26            26                                11-13-20 Post .pdf
# 52            52                          11-18-20 Penhaskashi.pdf
# 74            74                             11-13-20 Paperman.pdf
# ...          ...                                               ...
# 7574        7575                              7-30-20 Okoomian.pdf
# 7584        7585                                9-13-19 Takhsh.pdf
# 7600        7601  7-13-20 Armenian American Studies Collective.pdf
# 7654        7655                            10-7-20 Deurdulian.pdf
# 7701        7702                           10-23-20 Karapetian.pdf
#
#                                      folder_name  submissions    weight  \
# 1     Comments Received After September 30, 2020            1  0.000008
# ...

# %%
print(armenia['text'].iloc[9])
# Out:
# -----Original Message----From: [Emails redacted] Sent: Thursday, November 19, 2020 12:08 AM To: Ethnic Studies Subject: [EXTERNAL] CA Ethnic Studies must include West Asian Studies
#
# Dear Instructional Quality Commission of the California Board of Education,
#
# ...
