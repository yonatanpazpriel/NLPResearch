# %%
import pandas as pd

# %%
df = pd.read_csv('./all_files.csv')

# %%
df[df['text'].str.len() < 60].count()
# Out:
# Unnamed: 0     55
# file_name      55
# folder_name    55
# text           55
# submissions    55
# weight         55
# dtype: int64
