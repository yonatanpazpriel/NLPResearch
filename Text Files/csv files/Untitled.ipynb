# %%
import pandas as pd
# Out:
# /Users/maryamzakiyya/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('all_files.csv')
df
# Out:
#                         file_name                                 folder_name  \
# 0               11-13-20 Khan.pdf  Comments Received After September 30, 2020
# 1          11-13-20 Solkovits.pdf  Comments Received After September 30, 2020
# 2     11-13-20 Kaur and Singh.pdf  Comments Received After September 30, 2020
# 3             11-19-20 Lamont.pdf  Comments Received After September 30, 2020
# 4             11-18-20 Jensen.pdf  Comments Received After September 30, 2020
# ...                           ...                                         ...
# 7712          10-27-20 Parker.pdf  Comments Received After September 30, 2020
# 7713          10-30-20 Parker.pdf  Comments Received After September 30, 2020
# 7714            10-22-20 Nash.pdf  Comments Received After September 30, 2020
# 7715        10-27-20 Parker 2.pdf  Comments Received After September 30, 2020
# 7716        10-27-20 Fishkoff.pdf  Comments Received After September 30, 2020
#
#       submissions    weight  \
# ...

# %%
df['folder_name'].unique()
# Out:
# array(['Comments Received After September 30, 2020',
#        'Third Field Review (Dec 2020 - Jan 2021)',
#        'Second Field Review (Sept 2020)',
#        'Comments Received After Field Review',
#        'Comments received after Third Field Review (after 1-21-21)',
#        'First Field Review (June - August 2019)'], dtype=object)
